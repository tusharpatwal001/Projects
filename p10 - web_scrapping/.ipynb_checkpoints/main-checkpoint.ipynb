# %%
import pandas as pd

# %% [markdown]
# ## 1. Read a .csv from a URL with pandas

# %%
# reading csv from the link
df_premier24 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/E0.csv")

# %%
# showing dataframe
df_premier24.head()
# Out:
#   Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  16/08/2024  20:00  Man United       Fulham     1     0   H     0     0
# 1  E0  17/08/2024  12:30     Ipswich    Liverpool     0     2   A     0     0
# 2  E0  17/08/2024  15:00     Arsenal       Wolves     2     0   H     1     0
# 3  E0  17/08/2024  15:00     Everton     Brighton     0     3   A     0     1
# 4  E0  17/08/2024  15:00   Newcastle  Southampton     1     0   H     1     0
#
#    ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0  ...     1.86     2.07   1.83   2.11     1.88     2.11     1.82     2.05
# 1  ...     2.05     1.88   2.04   1.90     2.20     2.00     1.99     1.88
# 2  ...     2.02     1.91   2.00   1.90     2.05     1.93     1.99     1.87
# 3  ...     1.87     2.06   1.86   2.07     1.92     2.10     1.83     2.04
# 4  ...     1.87     2.06   1.88   2.06     1.89     2.10     1.82     2.05
#
#    BFECAHH  BFECAHA
# 0     1.90     2.08
# ...

# %%
# rename columns
df_premier24.rename(columns={'Date':'date'})
# Out:
#     Div        date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %% [markdown]
# ## 2. Read .csv from Multiple URLs with Pandas

# %%
# link structure
leagues = ["0", "1", "2", "3", "C"]
frames = []
for league in leagues:
    df = pd.read_csv("https://www.football-data.co.uk/mmz4281/2425/E"+ league +".csv")
    frames.append(df)

# %%
# length of frames
len(frames)
# Out:
# 5

# %%
# show 1st, 2nd and 3rd element

frames[:2]
# Out:
# [    Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
#  1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
#  2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
#  3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
#  4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
#  ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
#  375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
#  376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
#  377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
#  378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
#  379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
# all leagues with seasons
leagues = ["0", "1", "2", "3", "C"]
seasons = ["2021", "2122", "2223", "2324", "c425"]
frames = []
for season in seasons:
    for league in leagues:
        df = pd.read_csv("https://www.football-data.co.uk/mmz4281/"+ season +"/E"+ league +".csv", encoding="unicode_escape")
        frames.append(df)

# %%
len(frames)
# Out:
# 25

# %%
frames[3]
# Out:
#     Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E3  12/09/2020  15:00      Barrow       Stevenage     1     1   D     1
# 1    E3  12/09/2020  15:00      Bolton    Forest Green     0     1   A     0
# 2    E3  12/09/2020  15:00    Bradford      Colchester     0     0   D     0
# 3    E3  12/09/2020  15:00   Cambridge        Carlisle     3     0   H     2
# 4    E3  12/09/2020  15:00  Cheltenham       Morecambe     1     2   A     1
# ..   ..         ...    ...         ...             ...   ...   ...  ..   ...
# 547  E3  08/05/2021  15:00   Port Vale       Mansfield     0     3   A     0
# 548  E3  08/05/2021  15:00  Scunthorpe       Stevenage     0     1   A     0
# 549  E3  08/05/2021  15:00    Southend  Newport County     1     1   D     1
# 550  E3  08/05/2021  15:00    Tranmere      Colchester     0     0   D     0
# 551  E3  08/05/2021  16:00     Salford   Leyton Orient     3     0   H     1
#
# ...
